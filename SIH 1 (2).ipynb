# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('ranking.csv')

# %%
df
# Out:
#      institute_id                                               name  \
# 0     IR-E-U-0456              Indian Institute of Technology Madras
# 1     IR-E-I-1074               Indian Institute of Technology Delhi
# 2     IR-E-U-0306              Indian Institute of Technology Bombay
# 3     IR-E-I-1075              Indian Institute of Technology Kanpur
# 4     IR-E-U-0573           Indian Institute of Technology Kharagpur
# ..            ...                                                ...
# 195  IR-E-C-42227            Dr. D. Y. Patil Institute of Technology
# 196  IR-E-C-49660            Pimpri Chinchwad College of Engineering
# 197  IR-E-C-34167                Ramrao Adik Institute of Technology
# 198  IR-E-C-48145                                    BVRIT Hyderabad
# 199   IR-E-U-0615  National Institute of Technology Arunachal Pra...
#
#                                                   link    tlr    rpc     go  \
# ...

# %%
df.head()
# Out:
#   institute_id                                      name  \
# 0  IR-E-U-0456     Indian Institute of Technology Madras
# 1  IR-E-I-1074      Indian Institute of Technology Delhi
# 2  IR-E-U-0306     Indian Institute of Technology Bombay
# 3  IR-E-I-1075     Indian Institute of Technology Kanpur
# 4  IR-E-U-0573  Indian Institute of Technology Kharagpur
#
#                                                 link    tlr    rpc     go  \
# 0  https://nirfcdn.azureedge.net/2020/pdf/Enginee...  95.42  94.64  83.90
# 1  https://nirfcdn.azureedge.net/2020/pdf/Enginee...  90.79  96.15  80.36
# 2  https://nirfcdn.azureedge.net/2020/pdf/Enginee...  91.00  93.37  77.60
# 3  https://nirfcdn.azureedge.net/2020/pdf/Enginee...  86.22  82.08  88.44
# 4  https://nirfcdn.azureedge.net/2020/pdf/Enginee...  77.32  87.11  83.21
#
#       oi  perception       city          state  score  rank
# 0  61.31      100.00    Chennai     Tamil Nadu  89.93     1
# ...

# %%
#No use of link so it can be removed

# %%
df=df.drop(labels=['link'],axis=1)

# %%
name=df['name']

# %%
df=df.drop(labels=['name','state','city'],axis=1)

# %%
df
# Out:
#      institute_id    tlr    rpc     go     oi  perception  score  rank
# 0     IR-E-U-0456  95.42  94.64  83.90  61.31      100.00  89.93     1
# 1     IR-E-I-1074  90.79  96.15  80.36  64.81       94.46  88.08     2
# 2     IR-E-U-0306  91.00  93.37  77.60  49.99       92.51  85.08     3
# 3     IR-E-I-1075  86.22  82.08  88.44  54.21       85.78  82.18     4
# 4     IR-E-U-0573  77.32  87.11  83.21  56.62       89.31  80.56     5
# ..            ...    ...    ...    ...    ...         ...    ...   ...
# 195  IR-E-C-42227  49.69   1.66  53.63  48.50        1.63  31.15   196
# 196  IR-E-C-49660  46.11   7.36  50.73  48.76        0.55  31.13   197
# 197  IR-E-C-34167  53.60   3.82  45.75  47.25        0.00  31.11   198
# 198  IR-E-C-48145  49.16   0.46  53.74  52.98        1.63  31.10   199
# 199   IR-E-U-0615  50.56   9.06  39.36  46.21        7.12  31.09   200
#
# [200 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   institute_id  200 non-null    object
#  1   tlr           200 non-null    float64
#  2   rpc           200 non-null    float64
#  3   go            200 non-null    float64
#  4   oi            200 non-null    float64
#  5   perception    200 non-null    float64
#  6   score         200 non-null    float64
#  7   rank          200 non-null    int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 12.6+ KB

# %%
#4 objects found
#4 categorical variables

# %%
df.isnull().sum()
#No null values
# Out:
# institute_id    0
# tlr             0
# rpc             0
# go              0
# oi              0
# perception      0
# score           0
# rank            0
# dtype: int64

# %%
#We need to encode categorical variables
#one hot encoding and dummies encoding should be neglected
#LArge number of features
#if every count is unique then we can replace with frequency but frequency encoding not possible
#Now only ordinal and label encoding are possible

# %%
df.tail()
# Out:
#      institute_id    tlr   rpc     go     oi  perception  score  rank
# 195  IR-E-C-42227  49.69  1.66  53.63  48.50        1.63  31.15   196
# 196  IR-E-C-49660  46.11  7.36  50.73  48.76        0.55  31.13   197
# 197  IR-E-C-34167  53.60  3.82  45.75  47.25        0.00  31.11   198
# 198  IR-E-C-48145  49.16  0.46  53.74  52.98        1.63  31.10   199
# 199   IR-E-U-0615  50.56  9.06  39.36  46.21        7.12  31.09   200

# %%
df
# Out:
#      institute_id    tlr    rpc     go     oi  perception  score  rank
# 0     IR-E-U-0456  95.42  94.64  83.90  61.31      100.00  89.93     1
# 1     IR-E-I-1074  90.79  96.15  80.36  64.81       94.46  88.08     2
# 2     IR-E-U-0306  91.00  93.37  77.60  49.99       92.51  85.08     3
# 3     IR-E-I-1075  86.22  82.08  88.44  54.21       85.78  82.18     4
# 4     IR-E-U-0573  77.32  87.11  83.21  56.62       89.31  80.56     5
# ..            ...    ...    ...    ...    ...         ...    ...   ...
# 195  IR-E-C-42227  49.69   1.66  53.63  48.50        1.63  31.15   196
# 196  IR-E-C-49660  46.11   7.36  50.73  48.76        0.55  31.13   197
# 197  IR-E-C-34167  53.60   3.82  45.75  47.25        0.00  31.11   198
# 198  IR-E-C-48145  49.16   0.46  53.74  52.98        1.63  31.10   199
# 199   IR-E-U-0615  50.56   9.06  39.36  46.21        7.12  31.09   200
#
# [200 rows x 8 columns]

# %%
df.institute_id.unique()
# Out:
# array(['IR-E-U-0456', 'IR-E-I-1074', 'IR-E-U-0306', 'IR-E-I-1075',
#        'IR-E-U-0573', 'IR-E-U-0560', 'IR-E-U-0053', 'IR-E-U-0013',
#        'IR-E-U-0467', 'IR-E-U-0273', 'IR-E-U-0701', 'IR-E-U-0205',
#        'IR-E-U-0237', 'IR-E-U-0439', 'IR-E-U-0490', 'IR-E-U-0357',
#        'IR-E-U-0575', 'IR-E-U-0308', 'IR-E-U-0025', 'IR-E-U-0436',
#        'IR-E-U-0584', 'IR-E-U-0355', 'IR-E-U-0263', 'IR-E-U-0139',
#        'IR-E-U-0378', 'IR-E-U-0064', 'IR-E-U-0334', 'IR-E-U-0108',
#        'IR-E-I-1480', 'IR-E-U-0391', 'IR-E-U-0184', 'IR-E-U-0497',
#        'IR-E-U-0255', 'IR-E-U-0363', 'IR-E-U-0410', 'IR-E-U-0098',
#        'IR-E-U-0476', 'IR-E-U-0202', 'IR-E-U-0496', 'IR-E-U-0172',
#        'IR-E-U-0473', 'IR-E-U-0356', 'IR-E-U-0014', 'IR-E-C-16604',
#        'IR-E-C-7252', 'IR-E-U-0055', 'IR-E-U-0577', 'IR-E-U-0530',
#        'IR-E-C-37013', 'IR-E-C-41593', 'IR-E-U-0474', 'IR-E-U-0374',
#        'IR-E-U-0395', 'IR-E-U-0149', 'IR-E-U-0249', 'IR-E-U-0105',
# ...

# %%
df['institute_id']=df['institute_id'].str.split('-').str[3]

# %%
df
# Out:
#     institute_id    tlr    rpc     go     oi  perception  score  rank
# 0           0456  95.42  94.64  83.90  61.31      100.00  89.93     1
# 1           1074  90.79  96.15  80.36  64.81       94.46  88.08     2
# 2           0306  91.00  93.37  77.60  49.99       92.51  85.08     3
# 3           1075  86.22  82.08  88.44  54.21       85.78  82.18     4
# 4           0573  77.32  87.11  83.21  56.62       89.31  80.56     5
# ..           ...    ...    ...    ...    ...         ...    ...   ...
# 195        42227  49.69   1.66  53.63  48.50        1.63  31.15   196
# 196        49660  46.11   7.36  50.73  48.76        0.55  31.13   197
# 197        34167  53.60   3.82  45.75  47.25        0.00  31.11   198
# 198        48145  49.16   0.46  53.74  52.98        1.63  31.10   199
# 199         0615  50.56   9.06  39.36  46.21        7.12  31.09   200
#
# [200 rows x 8 columns]

# %%
did=df['institute_id']

# %%
df=df.drop(labels=['institute_id'],axis=1)

# %%
#one object found converting to string

# %%
df
# Out:
#        tlr    rpc     go     oi  perception  score  rank
# 0    95.42  94.64  83.90  61.31      100.00  89.93     1
# 1    90.79  96.15  80.36  64.81       94.46  88.08     2
# 2    91.00  93.37  77.60  49.99       92.51  85.08     3
# 3    86.22  82.08  88.44  54.21       85.78  82.18     4
# 4    77.32  87.11  83.21  56.62       89.31  80.56     5
# ..     ...    ...    ...    ...         ...    ...   ...
# 195  49.69   1.66  53.63  48.50        1.63  31.15   196
# 196  46.11   7.36  50.73  48.76        0.55  31.13   197
# 197  53.60   3.82  45.75  47.25        0.00  31.11   198
# 198  49.16   0.46  53.74  52.98        1.63  31.10   199
# 199  50.56   9.06  39.36  46.21        7.12  31.09   200
#
# [200 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tlr         200 non-null    float64
#  1   rpc         200 non-null    float64
#  2   go          200 non-null    float64
#  3   oi          200 non-null    float64
#  4   perception  200 non-null    float64
#  5   score       200 non-null    float64
#  6   rank        200 non-null    int64
# dtypes: float64(6), int64(1)
# memory usage: 11.1 KB

# %%
df['tlr']=df['tlr']*0.3
df['rpc']=df['rpc']*0.2
df['go']=df['go']*0.25
df['oi']=df['oi']*0.15
df['perception']=df['perception']*0.1

# %%
df
# Out:
#         tlr     rpc       go      oi  perception  score  rank
# 0    28.626  18.928  20.9750  9.1965      10.000  89.93     1
# 1    27.237  19.230  20.0900  9.7215       9.446  88.08     2
# 2    27.300  18.674  19.4000  7.4985       9.251  85.08     3
# 3    25.866  16.416  22.1100  8.1315       8.578  82.18     4
# 4    23.196  17.422  20.8025  8.4930       8.931  80.56     5
# ..      ...     ...      ...     ...         ...    ...   ...
# 195  14.907   0.332  13.4075  7.2750       0.163  31.15   196
# 196  13.833   1.472  12.6825  7.3140       0.055  31.13   197
# 197  16.080   0.764  11.4375  7.0875       0.000  31.11   198
# 198  14.748   0.092  13.4350  7.9470       0.163  31.10   199
# 199  15.168   1.812   9.8400  6.9315       0.712  31.09   200
#
# [200 rows x 7 columns]

# %%
#coverted to single datatype

# %%
plt.figure(figsize = (25,20))
sns.heatmap(df.corr(),annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=df['oi'])
# Out:
# <AxesSubplot:xlabel='oi'>

# %%
import numpy as np
df['oi']=np.where(df['oi']>10,10,df['oi'])
df['oi']=np.where(df['oi']<5.5,5.5,df['oi'])

# %%
sns.boxplot(x=df['perception'])
# Out:
# <AxesSubplot:xlabel='perception'>

# %%
import numpy as np
df['perception']=np.where(df['perception']>4,4,df['perception'])

# %%
import numpy as np
df['go']=np.where(df['go']>20,20,df['go'])
df['go']=np.where(df['go']<8,8,df['go'])

# %%
sns.boxplot(x=df['go'])
# Out:
# <AxesSubplot:xlabel='go'>

# %%
import numpy as np
df['rpc']=np.where(df['rpc']>12.5,12.5,df['rpc'])

# %%
sns.boxplot(x=df['rpc'])
# Out:
# <AxesSubplot:xlabel='rpc'>

# %%
import numpy as np
df['tlr']=np.where(df['tlr']>22.55,22.55,df['tlr'])

# %%
sns.boxplot(x=df['tlr'])
# Out:
# <AxesSubplot:xlabel='tlr'>

# %%
df
# Out:
#         tlr     rpc       go      oi  perception  score  rank
# 0    22.550  12.500  20.0000  9.1965       4.000  89.93     1
# 1    22.550  12.500  20.0000  9.7215       4.000  88.08     2
# 2    22.550  12.500  19.4000  7.4985       4.000  85.08     3
# 3    22.550  12.500  20.0000  8.1315       4.000  82.18     4
# 4    22.550  12.500  20.0000  8.4930       4.000  80.56     5
# ..      ...     ...      ...     ...         ...    ...   ...
# 195  14.907   0.332  13.4075  7.2750       0.163  31.15   196
# 196  13.833   1.472  12.6825  7.3140       0.055  31.13   197
# 197  16.080   0.764  11.4375  7.0875       0.000  31.11   198
# 198  14.748   0.092  13.4350  7.9470       0.163  31.10   199
# 199  15.168   1.812   9.8400  6.9315       0.712  31.09   200
#
# [200 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

x = df.drop('score',axis=1)
y = df['score']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.20,train_size=0.80,random_state=200)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (160, 6)
# (40, 6)
# (160,)
# (40,)

# %%
import warnings
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
dc=LinearRegression()

# %%
dc.fit(x_train,y_train)
pred1=dc.predict(x_test)
pd.DataFrame(np.c_[y_test,pred1],columns=['Actual','Predicted'])
# Out:
#     Actual  Predicted
# 0    35.49  34.106341
# 1    32.26  32.500676
# 2    31.23  31.910396
# 3    35.11  34.545115
# 4    51.79  54.455572
# 5    37.86  36.511539
# 6    56.56  61.165745
# 7    34.85  34.032505
# 8    33.79  33.180574
# 9    35.27  34.544321
# 10   39.44  38.184001
# 11   37.52  36.210436
# 12   34.27  34.842934
# 13   31.33  32.305174
# 14   37.10  40.967055
# 15   33.07  32.746077
# 16   36.13  35.085169
# 17   76.29  76.100765
# 18   33.67  32.727986
# 19   57.37  61.411465
# 20   33.57  33.164926
# 21   31.63  32.266049
# 22   32.69  32.732968
# 23   33.65  33.579394
# 24   38.21  36.812113
# 25   57.76  62.426416
# 26   32.04  32.114987
# 27   31.29  32.135854
# 28   36.84  35.985392
# 29   49.06  50.809701
# 30   50.07  51.164873
# 31   51.19  53.423509
# 32   40.24  39.513154
# 33   37.71  37.442612
# 34   62.06  67.637921
# 35   37.94  37.101883
# 36   32.72  32.872090
# 37   43.74  43.772886
# 38   36.54  35.766727
# 39   39.97  38.558239

# %%
dc_train=dc.score(x_train,y_train)*100
dc_test=dc.score(x_test,y_test)*100
mse=mean_squared_error(y_test,pred1)

# %%
print(mse)
print(dc_test)
# Out:
# 3.561805788894928
# 96.51286325887315

# %%
import xgboost as xgb

# %%
from lightgbm import LGBMRegressor

# %%
reg = LGBMRegressor()
reg.fit(x_train, y_train)
# Out:
# LGBMRegressor()

# %%
lgbm_pred = reg.predict(x_test)

# %%
print(mean_squared_error(y_test, lgbm_pred))
# Out:
# 5.682095519068509

# %%
pd.DataFrame(np.c_[y_test,lgbm_pred],columns=['Actual','Predicted'])
# Out:
#     Actual  Predicted
# 0    35.49  35.725453
# 1    32.26  32.415419
# 2    31.23  31.648061
# 3    35.11  35.023121
# 4    51.79  50.295593
# 5    37.86  38.516314
# 6    56.56  66.717464
# 7    34.85  34.599831
# 8    33.79  33.660301
# 9    35.27  34.980864
# 10   39.44  40.043061
# 11   37.52  37.718818
# 12   34.27  34.252162
# 13   31.33  31.596526
# 14   37.10  35.795530
# 15   33.07  33.076296
# 16   36.13  36.208877
# 17   76.29  73.752208
# 18   33.67  32.941600
# 19   57.37  60.616086
# 20   33.57  33.072666
# 21   31.63  31.485940
# 22   32.69  32.281414
# 23   33.65  33.749344
# 24   38.21  38.082729
# 25   57.76  64.324329
# 26   32.04  31.386306
# 27   31.29  31.296916
# 28   36.84  36.802233
# 29   49.06  53.123037
# 30   50.07  46.555589
# 31   51.19  47.474441
# 32   40.24  39.966189
# 33   37.71  38.008825
# 34   62.06  65.265930
# 35   37.94  36.217769
# 36   32.72  32.598079
# 37   43.74  42.810874
# 38   36.54  36.768156
# 39   39.97  40.558836

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBRegressor
xgb_reg = XGBRegressor()
xgb_reg.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
xgb_pred =xgb_reg.predict(x_test)
print(mean_squared_error(xgb_pred, y_test))
# Out:
# 0.24458873446907042

# %%
pd.DataFrame(np.c_[y_test,xgb_pred],columns=['Actual','Predicted'])
# Out:
#     Actual  Predicted
# 0    35.49  35.072906
# 1    32.26  32.132156
# 2    31.23  31.197294
# 3    35.11  34.888084
# 4    51.79  51.833515
# 5    37.86  37.670765
# 6    56.56  56.097172
# 7    34.85  34.686951
# 8    33.79  33.603947
# 9    35.27  35.065121
# 10   39.44  40.311836
# 11   37.52  37.223740
# 12   34.27  33.614582
# 13   31.33  31.297871
# 14   37.10  37.044304
# 15   33.07  32.907711
# 16   36.13  34.952465
# 17   76.29  74.972702
# 18   33.67  33.829266
# 19   57.37  58.346340
# 20   33.57  33.741028
# 21   31.63  31.479300
# 22   32.69  32.520184
# 23   33.65  33.621788
# 24   38.21  38.015335
# 25   57.76  57.669750
# 26   32.04  32.006233
# 27   31.29  31.337446
# 28   36.84  36.905380
# 29   49.06  49.227070
# 30   50.07  50.048832
# 31   51.19  51.007317
# 32   40.24  40.345310
# 33   37.71  38.112659
# 34   62.06  63.805882
# 35   37.94  38.138508
# 36   32.72  32.786999
# 37   43.74  43.302425
# 38   36.54  36.801929
# 39   39.97  40.208992

# %%
from sklearn.ensemble import StackingRegressor

# %%
from sklearn.datasets import load_diabetes
>>> from sklearn.linear_model import RidgeCV
>>> from sklearn.svm import LinearSVR
>>> from sklearn.ensemble import RandomForestRegressor
>>> from sklearn.ensemble import StackingRegressor

# %%
 estimators = [
...     ('lr', RidgeCV()),
...     ('svr', LinearSVR(random_state=42))
... ]

# %%
 reg = StackingRegressor(
...     estimators=estimators,
...     final_estimator=XGBRegressor(n_estimators=10,
...                                           random_state=42)
... )

# %%
reg.fit(x_train, y_train).score(x_test, y_test)
# Out:
# C:\Users\vijja\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\vijja\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\vijja\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\vijja\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %%
stacking=reg.predict(x_test)

# %%
pd.DataFrame(np.c_[y_test,stacking],columns=['Actual','Predicted'])
# Out:
#     Actual  Predicted
# 0    35.49  33.771252
# 1    32.26  31.748079
# 2    31.23  31.388353
# 3    35.11  33.771252
# 4    51.79  49.240395
# 5    37.86  36.538151
# 6    56.56  56.307209
# 7    34.85  33.771252
# 8    33.79  33.657188
# 9    35.27  33.771252
# 10   39.44  38.931889
# 11   37.52  36.538151
# 12   34.27  34.438354
# 13   31.33  31.388353
# 14   37.10  40.922737
# 15   33.07  31.748079
# 16   36.13  34.438354
# 17   76.29  79.044388
# 18   33.67  32.466835
# 19   57.37  56.307209
# 20   33.57  32.938423
# 21   31.63  31.622223
# 22   32.69  31.748079
# 23   33.65  33.657188
# 24   38.21  36.847343
# 25   57.76  56.307209
# 26   32.04  31.622223
# 27   31.29  31.018404
# 28   36.84  36.538151
# 29   49.06  48.250427
# 30   50.07  48.250427
# 31   51.19  49.240395
# 32   40.24  38.931889
# 33   37.71  36.847343
# 34   62.06  61.248753
# 35   37.94  36.847343
# 36   32.72  31.760262
# 37   43.74  42.249504
# 38   36.54  36.538151
# 39   39.97  38.931889

# %%
print(mean_squared_error(stacking, y_test))
# Out:
# 1.7325230665596991

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
neigh = KNeighborsRegressor(n_neighbors=2)

# %%
neigh.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=2)

# %%
neigh_pred=neigh.predict(x_test)

# %%
neigh_pred
# Out:
# array([35.66 , 32.3  , 31.185, 35.145, 51.835, 37.87 , 56.375, 34.77 ,
#        33.81 , 35.145, 39.665, 37.35 , 34.255, 31.335, 37.245, 33.065,
#        36.385, 77.73 , 33.81 , 57.92 , 33.48 , 31.66 , 32.6  , 33.64 ,
#        38.085, 57.75 , 32.04 , 31.28 , 36.815, 48.96 , 50.105, 51.185,
#        40.165, 37.685, 60.595, 38.085, 32.61 , 43.7  , 36.415, 39.955])

# %%
pd.DataFrame(np.c_[y_test,neigh_pred],columns=['Actual','Predicted'])
# Out:
#     Actual  Predicted
# 0    35.49     35.660
# 1    32.26     32.300
# 2    31.23     31.185
# 3    35.11     35.145
# 4    51.79     51.835
# 5    37.86     37.870
# 6    56.56     56.375
# 7    34.85     34.770
# 8    33.79     33.810
# 9    35.27     35.145
# 10   39.44     39.665
# 11   37.52     37.350
# 12   34.27     34.255
# 13   31.33     31.335
# 14   37.10     37.245
# 15   33.07     33.065
# 16   36.13     36.385
# 17   76.29     77.730
# 18   33.67     33.810
# 19   57.37     57.920
# 20   33.57     33.480
# 21   31.63     31.660
# 22   32.69     32.600
# 23   33.65     33.640
# 24   38.21     38.085
# 25   57.76     57.750
# 26   32.04     32.040
# 27   31.29     31.280
# 28   36.84     36.815
# 29   49.06     48.960
# 30   50.07     50.105
# 31   51.19     51.185
# 32   40.24     40.165
# 33   37.71     37.685
# 34   62.06     60.595
# 35   37.94     38.085
# 36   32.72     32.610
# 37   43.74     43.700
# 38   36.54     36.415
# 39   39.97     39.955

# %%
print(mean_squared_error(neigh_pred, y_test))
# Out:
# 0.12255062500000033

# %%
from sklearn.tree import DecisionTreeRegressor
DTregressor = DecisionTreeRegressor(random_state=0)
DTregressor.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
DT_pred=DTregressor.predict(x_test)

# %%
DT_pred
# Out:
# array([35.65, 32.36, 31.24, 34.87, 51.39, 37.77, 56.8 , 34.93, 33.87,
#        35.65, 39.93, 37.51, 34.17, 31.32, 37.1 , 33.24, 36.55, 80.56,
#        33.67, 57.14, 33.43, 31.74, 32.39, 33.75, 38.23, 58.7 , 32.08,
#        31.24, 36.72, 49.26, 50.95, 51.39, 40.58, 37.8 , 62.88, 37.94,
#        32.88, 44.7 , 36.55, 39.93])

# %%
print(mean_squared_error(DT_pred, y_test))
# Out:
# 0.5712799999999991

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regr = RandomForestRegressor(max_depth=2, random_state=0)
regr.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=0)

# %%
regr_pred=regr.predict(x_test)

# %%
print(mean_squared_error(regr_pred, y_test))
# Out:
# 3.478974868399285

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
ada_regr = AdaBoostRegressor(random_state=0, n_estimators=100)

# %%
ada_regr.fit(x_train, y_train)
# Out:
# AdaBoostRegressor(n_estimators=100, random_state=0)

# %%
ada_pred=ada_regr.predict(x_test)

# %%
pd.DataFrame(np.c_[y_test,ada_pred],columns=['Actual','Predicted'])
# Out:
#     Actual  Predicted
# 0    35.49  35.314242
# 1    32.26  32.970000
# 2    31.23  32.970000
# 3    35.11  34.721111
# 4    51.79  51.324375
# 5    37.86  37.789615
# 6    56.56  56.281667
# 7    34.85  34.471429
# 8    33.79  34.024524
# 9    35.27  35.042222
# 10   39.44  39.601111
# 11   37.52  37.542941
# 12   34.27  34.097778
# 13   31.33  32.970000
# 14   37.10  37.453333
# 15   33.07  33.008864
# 16   36.13  35.653462
# 17   76.29  81.058462
# 18   33.67  33.805758
# 19   57.37  56.936250
# 20   33.57  33.366061
# 21   31.63  32.970000
# 22   32.69  32.970000
# 23   33.65  33.366061
# 24   38.21  38.485263
# 25   57.76  58.203810
# 26   32.04  32.970000
# 27   31.29  32.970000
# 28   36.84  36.274138
# 29   49.06  49.041304
# 30   50.07  50.363077
# 31   51.19  51.006000
# 32   40.24  39.910800
# 33   37.71  37.764138
# 34   62.06  61.467500
# 35   37.94  38.056562
# 36   32.72  32.970000
# 37   43.74  44.586500
# 38   36.54  36.274138
# 39   39.97  39.829714

# %%
print(mean_squared_error(ada_pred, y_test))
# Out:
# 0.9512846421061605

# %%
from sklearn import linear_model
>>> clf = linear_model.Lasso(alpha=0.1)

# %%
clf.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.1)

# %%
clf_pred=clf.predict(x_test)

# %%
pd.DataFrame(np.c_[y_test,clf_pred],columns=['Actual','Predicted'])
# Out:
#     Actual  Predicted
# 0    35.49  34.331673
# 1    32.26  32.289447
# 2    31.23  31.875525
# 3    35.11  34.521042
# 4    51.79  54.526436
# 5    37.86  36.537565
# 6    56.56  60.783983
# 7    34.85  34.155849
# 8    33.79  33.274109
# 9    35.27  34.737639
# 10   39.44  38.507818
# 11   37.52  36.301830
# 12   34.27  34.765604
# 13   31.33  32.032279
# 14   37.10  41.225065
# 15   33.07  32.745100
# 16   36.13  35.251000
# 17   76.29  75.597810
# 18   33.67  32.887998
# 19   57.37  61.180453
# 20   33.57  33.335034
# 21   31.63  31.865009
# 22   32.69  32.797397
# 23   33.65  33.537816
# 24   38.21  37.090912
# 25   57.76  62.185487
# 26   32.04  32.050994
# 27   31.29  32.219463
# 28   36.84  36.219641
# 29   49.06  50.534622
# 30   50.07  50.962163
# 31   51.19  53.439988
# 32   40.24  39.580799
# 33   37.71  37.275452
# 34   62.06  67.347622
# 35   37.94  37.110377
# 36   32.72  32.909647
# 37   43.74  43.840554
# 38   36.54  35.954937
# 39   39.97  38.856793

# %%
from sklearn.linear_model import Ridge

# %%
ridge = Ridge(alpha=1.0)

# %%
ridge.fit(x_train, y_train)
# Out:
# Ridge()

# %%
ridge_pred=ridge.predict(x_test)

# %%
pd.DataFrame(np.c_[y_test,ridge_pred],columns=['Actual','Predicted'])
# Out:
#     Actual  Predicted
# 0    35.49  34.122454
# 1    32.26  32.482087
# 2    31.23  31.903423
# 3    35.11  34.546372
# 4    51.79  54.460948
# 5    37.86  36.512159
# 6    56.56  61.137516
# 7    34.85  34.042420
# 8    33.79  33.188938
# 9    35.27  34.562288
# 10   39.44  38.214351
# 11   37.52  36.218723
# 12   34.27  34.832499
# 13   31.33  32.281473
# 14   37.10  40.980226
# 15   33.07  32.744725
# 16   36.13  35.097176
# 17   76.29  76.054514
# 18   33.67  32.736614
# 19   57.37  61.387850
# 20   33.57  33.179880
# 21   31.63  32.234163
# 22   32.69  32.736137
# 23   33.65  33.577436
# 24   38.21  36.836749
# 25   57.76  62.406828
# 26   32.04  32.104535
# 27   31.29  32.140814
# 28   36.84  36.005851
# 29   49.06  50.788294
# 30   50.07  51.151796
# 31   51.19  53.423043
# 32   40.24  39.523018
# 33   37.71  37.436359
# 34   62.06  67.609206
# 35   37.94  37.107681
# 36   32.72  32.875396
# 37   43.74  43.782625
# 38   36.54  35.782035
# 39   39.97  38.584927

# %%
print(mean_squared_error(ridge_pred, y_test))
print(mean_squared_error(clf_pred, y_test))
# Out:
# 3.5247583484137897
# 3.1991160564231294
